# %% [markdown]
# Tic Tac Toe
# Reglas del Juego "Tic-Tac-Toe":
#
# El juego se juega en un tablero de 3x3.
# Dos jugadores, uno representa "X" y el otro "O", alternan turnos.
# El objetivo es obtener tres símbolos del mismo tipo en línea horizontal, vertical o diagonal.
# El juego termina cuando un jugador gana o el tablero se llena (empate).
# El jugador que logre colocar tres de sus símbolos en línea es el ganador.
#
# Pistas para las alumnas:
#
# Comienza creando una representación del tablero de juego utilizando una lista de listas para mantener un seguimiento de las jugadas.
# Implementa una función para imprimir el tablero en la pantalla en un formato claro y legible.
# Utiliza un bucle while para alternar los turnos de los jugadores y recopilar sus movimientos.
# Verifica después de cada movimiento si hay un ganador o si el juego termina en empate.
# Implementa una función que verifique si un jugador ha ganado alineando tres símbolos en fila, columna o diagonal.
# Asegurate de validar que una casilla seleccionada por un jugador no esté ocupada antes de permitir el movimiento.

# %%
#TABLERO CON "NONE"
L1 = ['None','|','None','|','None']

linea = ['______________________________']

L2= ['None','|','None','|','None']

L3= ['None','|','None','|','None']


print("-----------") #salto de funcion
# Out:
# -----------

# %%
linea_baja = 0
tablero=[L1,L2,L3]
for i in tablero:
    print(i)
    
    if linea_baja !=2 :    
        print(linea)
        linea_baja += 1
    else:
        linea_baja >= 2
# Out:
# ['None', '|', 'None', '|', 'None']
# ['______________________________']
# ['None', '|', 'None', '|', 'None']
# ['______________________________']
# ['None', '|', 'None', '|', 'None']

# %%
#TABLERO CON NÚMEROS
L1 = ['1','|','2','|','3']

linea = ['_____________________']

L2= ['4','|','5','|','6']

L3= ['7','|','8','|','9']

print("-----------") #salto de funcion

linea_baja = 0
tablero=[L1,L2,L3]
for i in tablero:
    print(i)
    
    if linea_baja !=2 :    
        print(linea)
        linea_baja += 1
    else:
        linea_baja >= 2
# Out:
# -----------
# ['1', '|', '2', '|', '3']
# ['_____________________']
# ['4', '|', '5', '|', '6']
# ['_____________________']
# ['7', '|', '8', '|', '9']

# %%
#TABLERO VACÍO
def imprimir_tablero(tablero):
    for i, fila in enumerate(tablero):
        # i es el índice de la fila: 0, 1, 2
        print(" | ".join(fila))
        if i != len(tablero) - 1:   # si no es la última fila
            print("-------------")
            
# Uso
mi_tablero = [
    ['  ', '  ', '  '],
    ['  ', '  ', '  '],
    ['  ', '  ', '  ']
]
imprimir_tablero(mi_tablero)
print(list(enumerate(tablero)))
# Out:
#    |    |
# -------------
#    |    |
# -------------
#    |    |
# [(0, [None, '|', None, '|', None]), (1, [None, '|', None, '|', None]), (2, [None, '|', None, '|', None])]

# %%
def imprimir_tablero(tablero):
    for indice,valor in enumerate(tablero):
        print("|".join(valor))
        if indice != len(tablero)-1:
            print("--------")

L1=["  ","  ","  "]
tablero_inicial=[L1,L1,L1]
imprimir_tablero(tablero_inicial)
# Out:
#   |  |
# --------
#   |  |
# --------
#   |  |

# %%
#SALUDO
print("¡Hola! Bienvenidos al clásico Tres en raya o Tic Tac Toe.")

def validar_jugadores():
    while True:
        try:
            jugadores=input("Para comenzar, ingresa el nombre del jugador 1 y 2 separados por una coma (','): ").strip().replace(" ","").upper()
            jugador_1,jugador_2=jugadores.split(",")
            
            if not jugadores:
                print("¡Ups! Parece que no has escrito nada. Vuelve a intentarlo.")
                continue
            elif not jugador_1 or not jugador_2:
                continue
            else:
                print (f"¡Buena Suerte {jugador_1} y {jugador_2}!\nComenzamos: ")
                return
        except:
            print("Algo ha salido mal, si quieres intentarlo de nuevo, ejecuta el programa.")
            break
# Out:
# ¡Hola! Bienvenidos al clásico Tres en raya o Tic Tac Toe.

# %%
validar_jugadores()
# Out:
# ¡Buena Suerte ANA, LAURA!
# Comenzamos:
